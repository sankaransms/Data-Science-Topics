# %% [markdown]
# # **Pandas Cheat Sheet📃**

# %% [markdown]
# <img src="https://media.licdn.com/dms/image/v2/D4D12AQEKIdttVBh55Q/article-cover_image-shrink_720_1280/article-cover_image-shrink_720_1280/0/1688538106780?e=1729728000&v=beta&t=2Djc6T5ODNSH9fXNnH3UbHAS852sEc2sJes5NgtfZs8">

# %% [markdown]
# # <font color="red">**1) IMPORTING**</font>

# %%
import pandas as pd

# %% [markdown]
# # <font color="red">**2) READING AND WRITTING DATA**</font>

# %%
# Syntax:
'''
# Reading data:
df = pd.read_csv(path = "file_name.csv")
'''
# Out:
# '\n# Reading data:\ndf = pd.read_csv(path = "file_name.csv")\n'

# %%
# Syntax:
'''
# Writing Data:
df.to_csv("file_name.csv", sep=",")
'''
# Out:
# '\n# Writing Data:\ndf.to_csv("file_name.csv", sep=",")\n'

# %% [markdown]
# # <font color="red">**3) SERIES AND DATAFRAME**</font>

# %% [markdown]
# ## <font color="orange">**3.1) Creating a Series**</font>

# %%
# Creating pd Series from list:
pd.Series(["a","b","c"])
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
type(pd.Series(["a","b","c"]))
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## <font color="orange">**3.2) Creating a DataFrame**</font>

# %% [markdown]
# ### <font color="morange">**3.2.1) Row oriented approach**</font>

# %%
# Row oriented approach -> Data -> 2D list, Column name -> List
pd.DataFrame([["a",1],["b",2]] , columns = ["name", "id"])
# Out:
#   name  id
# 0    a   1
# 1    b   2

# %%
type(pd.DataFrame([["a",1],["b",2]] , columns = ["name", "id"]))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###  <font color="morange">**3.2.2) Column oriented approach** </font>

# %%
# Column oriented approach
df = pd.DataFrame({
                   "name" : ["a","b","a","d","e","f"],
                   "id" : [1,2,3,4,5,6]
                 })
df
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4
# 4    e   5
# 5    f   6

# %% [markdown]
# # <font color="red">**4) INFO EXTRACTION**</font>

# %% [markdown]
# ## <font color="orange">**4.1) Shape**</font>

# %%
df.shape
# Out:
# (6, 2)

# %% [markdown]
# ## <font color="orange">**4.2) Head**</font>

# %%
df.head()
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4
# 4    e   5

# %% [markdown]
# ## <font color="orange">**4.3) Tail**</font>

# %%
df.tail()
# Out:
#   name  id
# 1    b   2
# 2    a   3
# 3    d   4
# 4    e   5
# 5    f   6

# %% [markdown]
# ## <font color="orange">**4.4) Info**</font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   id      6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 224.0+ bytes

# %% [markdown]
# ## <font color="orange">**4.5) Describe**</font>

# %%
# Gives the stasticial information of columns values
df.describe()
# Out:
#              id
# count  6.000000
# mean   3.500000
# std    1.870829
# min    1.000000
# 25%    2.250000
# 50%    3.500000
# 75%    4.750000
# max    6.000000

# %% [markdown]
# ## <font color="orange">**4.6) Value count - Group by count and arrange in descending order**</font>

# %%
df["name"].value_counts()
# Out:
# name
# a    2
# b    1
# d    1
# e    1
# f    1
# Name: count, dtype: int64

# %% [markdown]
# # <font color="red">**5) ACCESSING**</font>

# %% [markdown]
# ## <font color="orange">**5.1) Direct acessing of columns and rows, as well as both together**</font>

# %% [markdown]
# ### <font color="morange">**5.1.1) Acessing a row**</font>

# %%
# Cheking the index value:
df.index.values
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
# Creating index starting from 1:
ind = []
n = len(df.index.values)
for i in range(1,n+1):
  ind.append(i)
print(ind)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Creating index starting from 1 using list comprehension:
n = len(df.index.values)
ind = [i for i in range(1,n+1)]
print(ind)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Asigning "ind" list as index for df:
df.index = ind

# %%
df
# Out:
#   name  id
# 1    a   1
# 2    b   2
# 3    a   3
# 4    d   4
# 5    e   5
# 6    f   6

# %%
df.loc[1] #Explicit index (Visible), loc--> Location
# Out:
# name    a
# id      1
# Name: 1, dtype: object

# %%
df.iloc[0] #Implicit index (Invesible)
# Out:
# name    a
# id      1
# Name: 1, dtype: object

# %%
# Resetting the index back
df.reset_index(drop=True, inplace=True)
df
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4
# 4    e   5
# 5    f   6

# %% [markdown]
# ### <font color="morange">**5.1.2) Acessing column**</font>

# %%
# Accessing single column:
df["name"]
# Out:
# 0    a
# 1    b
# 2    a
# 3    d
# 4    e
# 5    f
# Name: name, dtype: object

# %%
# Acessing multiple columns:
df[["name", "id"]] #Note: For multiple col --> Double Square bracket
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4
# 4    e   5
# 5    f   6

# %% [markdown]
# ## <font color="orange">**5.2) Slicing**</font>

# %% [markdown]
# ### <font color="morange">**5.2.1) Row slicing**</font>

# %%
df.loc[0:3] #In Explicit indices end is inclusive
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4

# %%
df.iloc[0:3] #In Implicit indices, end is not inclusive
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3

# %% [markdown]
# ### <font color="morange">**5.2.1) Column Slicing**</font>

# %%
# syntax: df.loc["row", "col"]
df.loc[:,["name","id"]] # : --> all rows, column should be in the form of "name" since it is accessing location
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4
# 4    e   5
# 5    f   6

# %%
df.loc[:,"name":"id"] #From column "name" to "id"
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4
# 4    e   5
# 5    f   6

# %% [markdown]
# ### <font color="morange">**5.2.3) Both row and column**</font>

# %%
df.loc[0:3 , ["name","id"]] #Here 0 and 3 are explicit indices which means 3 is included
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4

# %% [markdown]
# ## <font color="orange">**5.3) Feature Exploration (Masking, Filtering)**</font>

# %% [markdown]
# ### <font color="morange">**5.3.1) Masking**</font>

# %%
# Filtering single column:
# Creating a mask based on condition:
mask = df["id"] > 2 #Returns a boolean
print(mask)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# Name: id, dtype: bool

# %%
# Masking the df:
df[mask]
# Out:
#   name  id
# 2    a   3
# 3    d   4
# 4    e   5
# 5    f   6

# %% [markdown]
# ### <font color="morange">**5.3.2) Filtering**</font>
#
# - Masking in multiple column is filtering

# %%
# Filtering based on conditions:
'''
df.loc[(df["col_1"] == value_1) & (df["col_2"] == value_2)]
df.loc[(df["col_1"] == value_1) | (df["col_2"] == value_2)]
'''
# Out:
# '\ndf.loc[(df["col_1"] == value_1) & (df["col_2"] == value_2)]\ndf.loc[(df["col_1"] == value_1) | (df["col_2"] == value_2)]\n'

# %%
# Conditions(OR): df.loc[() | ()]
df.loc[(df["id"] == 2) | (df["id"] == 3)]
# Out:
#   name  id
# 1    b   2
# 2    a   3

# %%
# Conditions(AND):
df.loc[(df["name"] == "a") & (df["id"] == 1)]
# Out:
#   name  id
# 0    a   1

# %% [markdown]
# # <font color="red">**6) DATAFRAME MANIPULATION**</font>

# %% [markdown]
# ## <font color="orange">**6.1) Adding a new row**</font>

# %%
df
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4
# 4    e   5
# 5    f   6

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.index.values
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
len(df.index)
# Out:
# 6

# %%
df.loc[5] # Last row for the current dataframe
# Out:
# name    f
# id      6
# Name: 5, dtype: object

# %%
# df.loc[6] #Index 6 is not available so there will be key error

# %%
# Appending a row to the end in the form of list:
df.loc[len(df.index)] = ["g", 7]
df
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4
# 4    e   5
# 5    f   6
# 6    g   7

# %% [markdown]
# ## <font color="orange">**6.2) Adding a new column**</font>

# %%
# Column
df["surname"] = ["Magesh", "Thanesh", "Kamesh", "Ram", "Shyam", "Vignesh", "Shiva"]
df
# Out:
#   name  id  surname
# 0    a   1   Magesh
# 1    b   2  Thanesh
# 2    a   3   Kamesh
# 3    d   4      Ram
# 4    e   5    Shyam
# 5    f   6  Vignesh
# 6    g   7    Shiva

# %% [markdown]
# ## <font color="orange">**6.3) Deleting row**</font>

# %%
# axis = 0 ---> Vertical -> Rows
# axis = 1 ---> Horizontal -> Columns

# %% [markdown]
# **keyword -> Drop**

# %%
# Droping single row:
df.drop(2 , axis = 0) # df.drop(2, axis = 0, inplace = True) -> inplace = True if needed to drop permenently
# 2 is explicit index
# axis = 0 -> Vertical
# Out:
#   name  id  surname
# 0    a   1   Magesh
# 1    b   2  Thanesh
# 3    d   4      Ram
# 4    e   5    Shyam
# 5    f   6  Vignesh
# 6    g   7    Shiva

# %%
# Droping Multiple rows:
df.drop([1,2,4] , axis = 0) # explicit index
# Out:
#   name  id  surname
# 0    a   1   Magesh
# 3    d   4      Ram
# 5    f   6  Vignesh
# 6    g   7    Shiva

# %% [markdown]
# ## <font color="orange">**6.4) Deleting Column**</font>

# %%
# axis = 0 ---> Vertical -> Rows
# axis = 1 ---> Horizontal -> Columns

# %%
df.drop("surname", axis = 1) # inplace = True if needed to drop permenently
# If needed to drop permenently use inplace = True after axis
# axis = 1 ---> Horizontal
# Out:
#   name  id
# 0    a   1
# 1    b   2
# 2    a   3
# 3    d   4
# 4    e   5
# 5    f   6
# 6    g   7

# %%
df.drop(columns = ["name","id"])
# If needed to drop permenently use inplace = True
# No need axis if column name is given like above
# Out:
#    surname
# 0   Magesh
# 1  Thanesh
# 2   Kamesh
# 3      Ram
# 4    Shyam
# 5  Vignesh
# 6    Shiva

# %% [markdown]
# ## <font color="orange">**6.5) Renaming row**</font>

# %%
df.index.values
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
n = len(df.index.values)
n
# Out:
# 7

# %%
# List comprehension istead of for loop:
# ind = [i for i in range(1,n+1)]

# %%
# Renaming index:
ind = []
for i in range(1,n+1):
  ind.append(i)
df.index = ind
df
# Out:
#   name  id  surname
# 1    a   1   Magesh
# 2    b   2  Thanesh
# 3    a   3   Kamesh
# 4    d   4      Ram
# 5    e   5    Shyam
# 6    f   6  Vignesh
# 7    g   7    Shiva

# %%
df.reset_index()
# Out:
#    index name  id  surname
# 0      1    a   1   Magesh
# 1      2    b   2  Thanesh
# 2      3    a   3   Kamesh
# 3      4    d   4      Ram
# 4      5    e   5    Shyam
# 5      6    f   6  Vignesh
# 6      7    g   7    Shiva

# %%
df.reset_index(drop = True, inplace = True)
df
# Out:
#   name  id  surname
# 0    a   1   Magesh
# 1    b   2  Thanesh
# 2    a   3   Kamesh
# 3    d   4      Ram
# 4    e   5    Shyam
# 5    f   6  Vignesh
# 6    g   7    Shiva

# %% [markdown]
# ## <font color="orange">**6.6) Renaming column**</font>

# %%
df
# Out:
#   name  id  surname
# 0    a   1   Magesh
# 1    b   2  Thanesh
# 2    a   3   Kamesh
# 3    d   4      Ram
# 4    e   5    Shyam
# 5    f   6  Vignesh
# 6    g   7    Shiva

# %%
# Syntax:
'''
df.rename({"old_name":"new_name"}, axis = 1) #If needed permenantly inplace = True
df.rename(columns = {"old_name":"new_name"}, inplace = True) #instead of axis = 1, can give as columns
'''
# Out:
# '\ndf.rename({"old_name":"new_name"}, axis = 1) #If needed permenantly inplace = True\ndf.rename(columns = {"old_name":"new_name"}, inplace = True) #instead of axis = 1, can give as columns\n'

# %%
df.rename({"name":"username","id":"user_id"}, axis = 1, inplace = True)

# %%
df
# Out:
#   username  user_id  surname
# 0        a        1   Magesh
# 1        b        2  Thanesh
# 2        a        3   Kamesh
# 3        d        4      Ram
# 4        e        5    Shyam
# 5        f        6  Vignesh
# 6        g        7    Shiva

# %%
df.rename(columns = {"surname":"sur_name"}, inplace = True)

# %%
df
# Out:
#   username  user_id sur_name
# 0        a        1   Magesh
# 1        b        2  Thanesh
# 2        a        3   Kamesh
# 3        d        4      Ram
# 4        e        5    Shyam
# 5        f        6  Vignesh
# 6        g        7    Shiva

# %% [markdown]
# ## <font color="orange">**6.7) Duplicates and Droping duplicates**</font>

# %%
# Creating a duplicate row:
df.loc[len(df.index)] = ["a", 1, "Magesh"]
df
# Out:
#   username  user_id sur_name
# 0        a        1   Magesh
# 1        b        2  Thanesh
# 2        a        3   Kamesh
# 3        d        4      Ram
# 4        e        5    Shyam
# 5        f        6  Vignesh
# 6        g        7    Shiva
# 7        a        1   Magesh

# %%
# Checking duplicates:
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# dtype: bool

# %%
# To print duplicate rows ---> masking
df.loc[df.duplicated()]
# Out:
#   username  user_id sur_name
# 7        a        1   Magesh

# %%
# Droping duplicates:
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#   username  user_id sur_name
# 0        a        1   Magesh
# 1        b        2  Thanesh
# 2        a        3   Kamesh
# 3        d        4      Ram
# 4        e        5    Shyam
# 5        f        6  Vignesh
# 6        g        7    Shiva

# %%
# Syntax:
'''
df.drop_duplicates(keep = "first")
df.drop_duplicates(keep = "last")
'''
# Out:
# '\ndf.drop_duplicates(keep = "first")\ndf.drop_duplicates(keep = "last")\n'

# %%
# Syntax:
'''
df.drop_duplicates(subset=['email'], keep='first', inplace=True)
'''
# Out:
# "\ndf.drop_duplicates(subset=['email'], keep='first', inplace=True)\n"

# %% [markdown]
# # <font color="red">**7) OPERATIONS**</font>

# %% [markdown]
# ## <font color="orange">**7.1) Sorting**</font>

# %%
df
# Out:
#   username  user_id sur_name
# 0        a        1   Magesh
# 1        b        2  Thanesh
# 2        a        3   Kamesh
# 3        d        4      Ram
# 4        e        5    Shyam
# 5        f        6  Vignesh
# 6        g        7    Shiva

# %%
# Syntax:
'''
df.sort_values(["column_name"]) #Default ascending = True
df.sort_values(["column_name"], ascending = False)
df.sort_values(["col_1","col_2"], ascending = [True,False])
'''
# Out:
# '\ndf.sort_values(["column_name"]) #Default ascending = True\ndf.sort_values(["column_name"], ascending = False)\ndf.sort_values(["col_1","col_2"], ascending = [True,False])\n'

# %%
df.sort_values(["username"], ascending=True) # Default ascending = True
# Out:
#   username  user_id sur_name
# 0        a        1   Magesh
# 2        a        3   Kamesh
# 1        b        2  Thanesh
# 3        d        4      Ram
# 4        e        5    Shyam
# 5        f        6  Vignesh
# 6        g        7    Shiva

# %%
df.sort_values(["username"], ascending=False)
# Out:
#   username  user_id sur_name
# 6        g        7    Shiva
# 5        f        6  Vignesh
# 4        e        5    Shyam
# 3        d        4      Ram
# 1        b        2  Thanesh
# 0        a        1   Magesh
# 2        a        3   Kamesh

# %%
df.sort_values(["username","user_id"], ascending=[True, False])
# Out:
#   username  user_id sur_name
# 2        a        3   Kamesh
# 0        a        1   Magesh
# 1        b        2  Thanesh
# 3        d        4      Ram
# 4        e        5    Shyam
# 5        f        6  Vignesh
# 6        g        7    Shiva

# %% [markdown]
# ## <font color="orange">**7.2) Build in operations**</font>

# %% [markdown]
# Sum, Mean, Min, Max, count

# %%
# Syntax:
'''
df["column_name"].sum()
df["column_name"].mean()
df["column_name"].min()
df["column_name"].max()
df["column_name"].count()
'''
# Out:
# '\ndf["column_name"].sum()\ndf["column_name"].mean()\ndf["column_name"].min()\ndf["column_name"].max()\ndf["column_name"].count()\n'

# %% [markdown]
# ## <font color="orange">**7.3) Apply**</font>
#
# - Taking each element row by row and performing some operation

# %%
# Reading a new csv file:
data = pd.read_csv("/content/drive/MyDrive/Dataset for Pandas cheat sheet/data.csv")
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name gender
# 0         4762  2009   Dec  Thursday      James Cameron   Male
# 1         4763  2007   May  Saturday     Gore Verbinski   Male
# 2         4764  2015   Oct    Monday         Sam Mendes   Male
# ...

# %%
# Syntax:
'''
df["column_name"].apply(function)

Note:
For double column operation use axis:
df[["Revenue","Budget"]].apply(np.sum, axis = 1) #axis = 0 by defult, axis = 1 for Horizontal

df["column_name"].apply(lambda x: x+10)
'''
# Out:
# '\ndf["column_name"].apply(function)\n\nNote:\nFor double column operation use axis:\ndf[["Revenue","Budget"]].apply(np.sum, axis = 1) #axis = 0 by defult, axis = 1 for Horizontal\n\ndf["column_name"].apply(lambda x: x+10)\n'

# %% [markdown]
# **Task:**
#
# Give encoding to the Genders: Male --> 0 , Female --> 1

# %%
# apply()
def function_name(x):
  if x == "Male":
    return 0
  else:
    return 1

data["gender"] = data["gender"].apply(function_name) # Default axis = 0
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  gender
# 0         4762  2009   Dec  Thursday      James Cameron       0
# 1         4763  2007   May  Saturday     Gore Verbinski       0
# 2         4764  2015   Oct    Monday         Sam Mendes       0
# ...

# %% [markdown]
# **Note:**
#
# For double column operation use axis

# %%
# Vertical sum:
import numpy as np
data[["revenue","budget"]].apply(np.sum) # axis = 0 by defult
# Out:
# revenue    209867.04
# budget      70353.62
# dtype: float64

# %%
# Horizontal sum:
data[["revenue","budget"]].apply(np.sum, axis = 1) # axis = 1 for Horizontal
# Out:
# 0       3024.97
# 1       1261.00
# 2       1125.67
# 3       1334.94
# 4       1148.87
#          ...
# 1460       0.32
# 1461       3.18
# 1462       0.00
# 1463       0.00
# 1464       2.26
# Length: 1465, dtype: float64

# %% [markdown]
# **Task:**
#
# Create a column pofit by using cols revenue and budget

# %%
# Creating a column pofit by using cols revenue and budget
def function_profit(df):
  profit = df["revenue"] - df["budget"]
  return profit

data["profit"] = data[["revenue","budget"]].apply(function_profit, axis = 1) # For double column operation use axis
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  gender   profit
# 0         4762  2009   Dec  Thursday      James Cameron       0  2550.97
# 1         4763  2007   May  Saturday     Gore Verbinski       0   661.00
# 2         4764  2015   Oct    Monday         Sam Mendes       0   635.67
# ...

# %%
# Profit calculation using lambda function
data[["revenue","budget"]].apply(lambda x: x['revenue'] - x['budget'], axis=1)
# Out:
# 0       2550.97
# 1        661.00
# 2        635.67
# 3        834.94
# 4        632.87
#          ...
# 1460       0.32
# 1461       3.12
# 1462       0.00
# 1463       0.00
# 1464       1.82
# Length: 1465, dtype: float64

# %%
# apply using Lambda function:
data["vote_average"].apply(lambda x: x*10)
# Out:
# 0       72.0
# 1       69.0
# 2       63.0
# 3       76.0
# 4       59.0
#         ...
# 1460    79.0
# 1461    74.0
# 1462    60.0
# 1463    64.0
# 1464    66.0
# Name: vote_average, Length: 1465, dtype: float64

# %% [markdown]
# # <font color="red">**8) JOINS**</font>

# %% [markdown]
# ## <font color="orange">**8.1) Concat**</font>
#
# - Works like stacking

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Preparing data -> Creating a table by column oriented approah:
users = pd.DataFrame({"userid":[1, 2, 3], "name":["Srinivas", "Prem", "Prashant"]})
users
# Out:
#    userid      name
# 0       1  Srinivas
# 1       2      Prem
# 2       3  Prashant

# %%
# Preparing data -> Creating a table by column oriented approah:
msgs = pd.DataFrame({"userid":[1, 1, 2, 4], "msg":['hmm', "acha", "theek hai", "nice"]})
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
# Syntax:
'''
pd.concat([df1,df2],axis = 0) #axis = 1 for horizontal
pd.concat([df1,df2],axis = 0, ignore_index = True) #This will arange the index properly
'''
# Out:
# '\npd.concat([df1,df2],axis = 0) #axis = 1 for horizontal\npd.concat([df1,df2],axis = 0, ignore_index = True) #This will arange the index properly\n'

# %%
pd.concat([users,msgs], axis = 0, ignore_index=True) #axis = 1 for horizontal
# Out:
#    userid      name        msg
# 0       1  Srinivas        NaN
# 1       2      Prem        NaN
# 2       3  Prashant        NaN
# 3       1       NaN        hmm
# 4       1       NaN       acha
# 5       2       NaN  theek hai
# 6       4       NaN       nice

# %%
pd.concat([users,msgs], axis=1)
# Out:
#    userid      name  userid        msg
# 0     1.0  Srinivas       1        hmm
# 1     2.0      Prem       1       acha
# 2     3.0  Prashant       2  theek hai
# 3     NaN       NaN       4       nice

# %% [markdown]
# ## <font color="orange">**8.2) Merge**</font>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
users
# Out:
#    userid      name
# 0       1  Srinivas
# 1       2      Prem
# 2       3  Prashant

# %%
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
# Syntax:
'''
df1.merge(df2 , on = "foreign_key", how = "type_of_join")
#how = "inner" ---> is default

df1.merge(df2 , left_on = "col_name(df1)", right_on = "col_name(df2)", how = "type_of_join")
'''
# Out:
# '\ndf1.merge(df2 , on = "foreign_key", how = "type_of_join")\n#how = "inner" ---> is default\n\ndf1.merge(df2 , left_on = "col_name(df1)", right_on = "col_name(df2)", how = "type_of_join")\n'

# %%
# Defauld Inner join:
users.merge(msgs, on="userid") # Default: inner join
# Out:
#    userid      name        msg
# 0       1  Srinivas        hmm
# 1       1  Srinivas       acha
# 2       2      Prem  theek hai

# %%
# Left join:
users.merge(msgs, on="userid", how="left")
# Out:
#    userid      name        msg
# 0       1  Srinivas        hmm
# 1       1  Srinivas       acha
# 2       2      Prem  theek hai
# 3       3  Prashant        NaN

# %%
# Right join:
users.merge(msgs, on = "userid", how = "right")
# Out:
#    userid      name        msg
# 0       1  Srinivas        hmm
# 1       1  Srinivas       acha
# 2       2      Prem  theek hai
# 3       4       NaN       nice

# %% [markdown]
# # <font color="red">**9) GROUPBY**</font>

# %% [markdown]
# Simply it could be understood through the terms - Split, apply, combine
#
# <img src="https://learning.oreilly.com/api/v2/epubs/urn:orm:book:9781491912126/files/assets/pyds_03in01.png" height = 350/>
#
# 1. **Split**: **Breaking up and grouping** a DataFrame depending on the value of the specified key.
#
# 2. **Apply**: Computing **some functio**n, usually an **aggregate, transformation, or filtering**, within the individual groups.
#
# 3. **Combine**: **Merge the results** of these operations into an output array.
#
# > Note: All these steps are to understand the topic

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <font color="orange">**9.1) Group by basic operations**</font>

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  gender   profit
# 0         4762  2009   Dec  Thursday      James Cameron       0  2550.97
# 1         4763  2007   May  Saturday     Gore Verbinski       0   661.00
# 2         4764  2015   Oct    Monday         Sam Mendes       0   635.67
# ...

# %%
# Syntax:
'''
dataframe.groupby("column_name").ngroups #To get number of groups in grouped by column
dataframe.groupby("column_name").groups #To diaplay the groups and its indices in the form of dictionary
dataframe.groupby("column_name").get_group("group_key") #To display a group like data frame
'''
# Out:
# '\ndataframe.groupby("column_name").ngroups #To get number of groups in grouped by column\ndataframe.groupby("column_name").groups #To diaplay the groups and its indices in the form of dictionary\ndataframe.groupby("column_name").get_group("group_key") #To display a group like data frame\n'

# %%
# Performing group by on Director name:
data.groupby("director_name")

# %%
# To get number of groups in grouped by column:
data.groupby("director_name").ngroups
# Out:
# 199

# %%
# To diaplay the groups and its indices in the form of dictionary
data.groupby("director_name").groups
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 
# ...

# %%
# To display a group like data frame:
data.groupby("director_name").get_group("Adam McKay")
# Out:
#       id_x  budget  popularity  revenue  \
# 176  43882   100.0          24   170.43
# 323  44151    72.5          12   162.97
# 366  44236    65.0          22   128.11
# 505  44503    50.0          38   173.65
# 839  45301    28.0          57   133.35
# 916  45443    26.0          29    90.57
#
#                                            title  vote_average  vote_count  \
# 176                               The Other Guys           6.1        1383
# 323  Talladega Nights: The Ballad of Ricky Bobby           6.2         491
# 366                                Step Brothers           6.5        1062
# 505            Anchorman 2: The Legend Continues           6.0         923
# 839                                The Big Short           7.3        2607
# 916        Anchorman: The Legend of Ron Burgundy           6.7        1493
#
#      director_id  year month        day director_name  gender  profit
# 176         4925  2010   Aug     Friday    Adam McKay       0   70.43
# ...

# %% [markdown]
# ## <font color="orange">**9.2) Group by single aggregation**</font>

# %%
# Syntax:
'''
dataframe.groupby("column_name")["col(s)"].aggregation_function()

dataframe.groupby("director_name")["title"].count()
'''
# Out:
# '\ndataframe.groupby("column_name")["col(s)"].aggregation_function()\n\ndataframe.groupby("director_name")["title"].count()\n'

# %% [markdown]
# <font color="morange">**Q) Print the number of movies each director directed**</font>

# %%
# Print the number of movies each director directed:
data.groupby("director_name")["title"].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %% [markdown]
# ## <font color="orange">**9.3) Group by multiple aggrgations**</font>

# %%
data.head(2)
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
#
#    director_id  year month       day   director_name  gender   profit
# 0         4762  2009   Dec  Thursday   James Cameron       0  2550.97
# 1         4763  2007   May  Saturday  Gore Verbinski       0   661.00

# %%
# Syntax:

## Type 1:
'''
dataframe.groupby("director_name")["year"].aggregate(["min","max"])

data_agg = data.groupby("director_name")[["year", "title"]].aggregate({
                                                                       "year":["min","max"],
                                                                       "title": "count"
                                                                      })

# Simplified version of the above code:
data.groupby("director_name")[["year", "title"]].aggregate(
                                                           year_min = ("year", "min"),
                                                           year_max = ("year", "max"),
                                                           title_count = ("title", "count")
                                                          )
'''

## Type 2: After groupby How do you want to display each column
'''
dataframe.groupby("director_name").agg({
                                        "vote_average":["mean", "min", "max"]
                                      })

Example:
# Creating a dictionary for aggregation at segment level

segment_dict = {
  'trip_uuid' : 'first',
  'data': 'first',
  'route_type': 'first',
  'trip_creation_time': 'first',
  'source_name': 'first',
  'destination_name': 'last',
  'od_start_time': 'first',
  'od_end_time': 'last',
  'start_scan_to_end_scan': 'first',
  'actual_distance_to_destination': 'last',
  'actual_time': 'last',
  'osrm_time': 'last',
  'osrm_distance': 'last',
  'segment_actual_time' : 'sum',
  'segment_osrm_time' : 'sum',
  'segment_osrm_distance' : 'sum',
  'segment_actual_time_sum': 'last',
  'segment_osrm_time_sum': 'last',
  'segment_osrm_distance_sum': 'last',
}

# Grouping by segment_key and aggregating
segment_df = df.groupby('segment_key').agg(segment_dict).reset_index()
'''
# Out:
# '\ndataframe.groupby("director_name").agg({\n                                        "vote_average":["mean", "min", "max"]\n                                      })\n\nExample:\n# Creating a dictionary for aggregation at segment level\n\nsegment_dict = {\n  \'trip_uuid\' : \'first\',\n  \'data\': \'first\',\n  \'route_type\': \'first\',\n  \'trip_creation_time\': \'first\',\n  \'source_name\': \'first\',\n  \'destination_name\': \'last\',\n  \'od_start_time\': \'first\',\n  \'od_end_time\': \'last\',\n  \'start_scan_to_end_scan\': \'first\',\n  \'actual_distance_to_destination\': \'last\',\n  \'actual_time\': \'last\',\n  \'osrm_time\': \'last\',\n  \'osrm_distance\': \'last\',\n  \'segment_actual_time\' : \'sum\',\n  \'segment_osrm_time\' : \'sum\',\n  \'segment_osrm_distance\' : \'sum\',\n  \'segment_actual_time_sum\': \'last\',\n  \'segment_osrm_time_sum\': \'last\',\n  \'segment_osrm_distance_sum\': \'last\',\n}\n\n# Grouping by segment_key and aggregating\nsegment_df = df.groupb
# ...

# %% [markdown]
# **<font color="morange">Q) For every director, Find the first year and the last year in which they have directed a movie?**</font>

# %%
# Groupby single aggregation -> Can be optimized:
data.groupby("director_name")["year"].min()
# Out:
# director_name
# Adam McKay                     2004
# Adam Shankman                  2001
# Alejandro González Iñárritu    2000
# Alex Proyas                    1994
# Alexander Payne                1999
#                                ...
# Wes Craven                     1984
# Wolfgang Petersen              1981
# Woody Allen                    1977
# Zack Snyder                    2004
# Zhang Yimou                    2002
# Name: year, Length: 199, dtype: int64

# %%
# Groupby single aggregation -> Can be optimized:
data.groupby("director_name")["year"].max()
# Out:
# director_name
# Adam McKay                     2015
# Adam Shankman                  2012
# Alejandro González Iñárritu    2015
# Alex Proyas                    2016
# Alexander Payne                2013
#                                ...
# Wes Craven                     2011
# Wolfgang Petersen              2006
# Woody Allen                    2013
# Zack Snyder                    2016
# Zhang Yimou                    2014
# Name: year, Length: 199, dtype: int64

# %%
# Groupby "director_name" on top of "year" multiple aggregations (["min", "max"])
data.groupby("director_name")["year"].aggregate(["min","max"])
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %% [markdown]
# <font color="morange">**Q) Which director would be considered as most productive?**</font>

# %%
# Value counts just give the total counts but we need the productivity:
data["director_name"].value_counts()
# Out:
# director_name
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: count, Length: 199, dtype: int64

# %% [markdown]
# productive as: number of movies/year.
#
# Need to find how much years a director is active:
# For that we need to find group by directors and min and max in year col,
# count of movies in title col.
#
# Note:
# Year col ---> min, max
# title col ---> count

# %%
data_agg = data.groupby("director_name")[["year", "title"]].aggregate({
                                                                       "year":["min","max"],
                                                                       "title": "count"
                                                                      })
data_agg
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5
# ...                           ...   ...   ...
# Wes Craven                   1984  2011    10
# Wolfgang Petersen            1981  2006     7
# Woody Allen                  1977  2013    18
# Zack Snyder                  2004  2016     7
# Zhang Yimou                  2002  2014     6
#
# [199 rows x 3 columns]

# %%
data_agg.columns
# Out:
# MultiIndex([( 'year',   'min'),
#             ( 'year',   'max'),
#             ('title', 'count')],
#            )

# %%
new_col = ["_".join(elem) for elem in data_agg.columns]
new_col
# Out:
# ['year_min', 'year_max', 'title_count']

# %%
data_agg.columns = new_col
data_agg.reset_index(inplace=True)

# %%
data_agg.head()
# Out:
#                  director_name  year_min  year_max  title_count
# 0                   Adam McKay      2004      2015            6
# 1                Adam Shankman      2001      2012            8
# 2  Alejandro González Iñárritu      2000      2015            6
# 3                  Alex Proyas      1994      2016            5
# 4              Alexander Payne      1999      2013            5

# %%
# Creating "yrs_active" column:
data_agg["yrs_active"] = data_agg["year_max"] - data_agg["year_min"]
data_agg.head()
# Out:
#                  director_name  year_min  year_max  title_count  yrs_active
# 0                   Adam McKay      2004      2015            6          11
# 1                Adam Shankman      2001      2012            8          11
# 2  Alejandro González Iñárritu      2000      2015            6          15
# 3                  Alex Proyas      1994      2016            5          22
# 4              Alexander Payne      1999      2013            5          14

# %%
# Calculating the movies per year column:
data_agg["movies_per_yr"] = data_agg["title_count"] / data_agg["yrs_active"]
data_agg.head()
# Out:
#                  director_name  year_min  year_max  title_count  yrs_active  \
# 0                   Adam McKay      2004      2015            6          11
# 1                Adam Shankman      2001      2012            8          11
# 2  Alejandro González Iñárritu      2000      2015            6          15
# 3                  Alex Proyas      1994      2016            5          22
# 4              Alexander Payne      1999      2013            5          14
#
#    movies_per_yr
# 0       0.545455
# 1       0.727273
# 2       0.400000
# 3       0.227273
# 4       0.357143

# %%
# Inorder to find the most productive director:
data_agg.sort_values(["movies_per_yr"], ascending = False)
# Out:
#         director_name  year_min  year_max  title_count  yrs_active  \
# 190       Tyler Perry      2006      2013            9           7
# 73    Jason Friedberg      2006      2010            5           4
# 169        Shawn Levy      2002      2014           11          12
# 158  Robert Rodriguez      1992      2014           16          22
# 1       Adam Shankman      2001      2012            8          11
# ..                ...       ...       ...          ...         ...
# 104   Lawrence Kasdan      1985      2012            5          27
# 109        Luc Besson      1985      2014            5          29
# 157    Robert Redford      1980      2010            5          30
# 170      Sidney Lumet      1976      2006            5          30
# 117     Michael Apted      1980      2010            5          30
#
#      movies_per_yr
# 190       1.285714
# 73        1.250000
# 169       0.916667
# 158       0.727273
# 1         0.727273
# ..             ...
# ...

# %% [markdown]
# <font color="morange">**Simplified version of the code**</font>

# %%
# Syntax:
'''
data_agg = data.groupby("director_name")[["year", "title"]].aggregate({
                                                                       "year":["min","max"],
                                                                       "title": "count"
                                                                      })
data_agg
'''
# Simplified version of the above code:
data.groupby("director_name")[["year", "title"]].aggregate(
                                                           year_min = ("year", "min"),
                                                           year_max = ("year", "max"),
                                                           title_count = ("title", "count")
                                                          )
# Out:
#                              year_min  year_max  title_count
# director_name
# Adam McKay                       2004      2015            6
# Adam Shankman                    2001      2012            8
# Alejandro González Iñárritu      2000      2015            6
# Alex Proyas                      1994      2016            5
# Alexander Payne                  1999      2013            5
# ...                               ...       ...          ...
# Wes Craven                       1984      2011           10
# Wolfgang Petersen                1981      2006            7
# Woody Allen                      1977      2013           18
# Zack Snyder                      2004      2016            7
# Zhang Yimou                      2002      2014            6
#
# [199 rows x 3 columns]

# %% [markdown]
# ## <font color="orange">**9.3) Groupby -> Filter - (like Group by and having in SQL)**</font>
#
# - Grouped by Dataframe and on top of it perform aggregation and then filter on a column.

# %% [markdown]
# <font color="morange">**Q) Give the details of the movies by high budget directors:**</font>
#
# - For finding the details of the movies by high budget directors lets assume, high budget director -> any director with **atleast one movie with budget >100M**

# %% [markdown]
# ### <font color="morange">**Lets solve the above question in three steps**</font>
#
# **Learnings:**
# - Use case of `names = data_dir_budget.loc[data_dir_budget["budget"] > 100,"director_name"]`
# - Use case of `data.loc[data["director_name"].isin(names)]`
#
#
# **Steps:**
# - STEP 1: Group by -> aggregation
# - STEP 2: From the grouped by dataframe -> Filtering
# - STEP 3: To get the details of those movies directed by the "names"

# %%
# STEP 1: Group by -> aggregation:
data_dir_budget = data.groupby("director_name")["budget"].max().reset_index()
data_dir_budget.head()
# Out:
#                  director_name  budget
# 0                   Adam McKay   100.0
# 1                Adam Shankman    80.0
# 2  Alejandro González Iñárritu   135.0
# 3                  Alex Proyas   140.0
# 4              Alexander Payne    30.0

# %%
# STEP 2: From the grouped by dataframe -> Filtering
names = data_dir_budget.loc[data_dir_budget["budget"] > 100,"director_name"]
names
# Out:
# 2      Alejandro González Iñárritu
# 3                      Alex Proyas
# 5                   Andrew Adamson
# 10                         Ang Lee
# 15                Barry Sonnenfeld
#                   ...
# 185                      Tim Story
# 187                    Tom Shadyac
# 188                     Tom Tykwer
# 195              Wolfgang Petersen
# 197                    Zack Snyder
# Name: director_name, Length: 79, dtype: object

# %%
# STEP 3: To get the details of those movies directed by the "names"
data.loc[data["director_name"].isin(names)]
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1450  48267    0.40          33   100.00
# 1451  48268    0.20          13     4.51
# 1452  48274    0.00           5     2.61
# 1458  48335    0.06          27     3.22
# 1460  48363    0.00           3     0.32
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %% [markdown]
# ### <font color="morange">**Lets solve the above question in a single step using using groupby filter()**</font>
#
# - Use case of `data.groupby("director_name").filter(lambda x: x["budget"].max() > 100)`
#
# - Display only those rows where budget > 100 M after groupby("director_name") --> using groupby **filter()**

# %%
# This filters all rows of those directors whose max budgt is greater than 100 million after grouped by a column:
data.groupby("director_name").filter(lambda x: x["budget"].max() > 100)
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1450  48267    0.40          33   100.00
# 1451  48268    0.20          13     4.51
# 1452  48274    0.00           5     2.61
# 1458  48335    0.06          27     3.22
# 1460  48363    0.00           3     0.32
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %% [markdown]
# ## <font color="orange">**9.4) Group based apply**</font>

# %% [markdown]
# <font color="morange">**Q) Categorize a movie as risky or non-risky, a movie is risky, if its budget is greater than the average revenue of all the movies of that director**</font>

# %%
# Function to check risky investments
def check_risky(df):
    mean_revenue = df["revenue"].mean()
    risky_flag = df["budget"] > mean_revenue
    return risky_flag

# Apply the function and create the "risky" column
risky_flags = data.groupby("director_name").apply(lambda group: check_risky(group)).reset_index(level=0, drop=True)
data["risky"] = risky_flags
data
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %% [markdown]
# # <font color="red">**10) CLEANING OUR DATA**</font>

# %% [markdown]
# ## <font color="orange">**10.1) None and NaN**</font>

# %%
# Creating a income column with null values
import numpy as np
df["income"] = [1000,2000,np.nan,np.nan,4000,6000,7000]
df
# Out:
#   username  user_id sur_name  income
# 0        a        1   Magesh  1000.0
# 1        b        2  Thanesh  2000.0
# 2        a        3   Kamesh     NaN
# 3        d        4      Ram     NaN
# 4        e        5    Shyam  4000.0
# 5        f        6  Vignesh  6000.0
# 6        g        7    Shiva  7000.0

# %%
type(None)
# Out:
# NoneType

# %%
import numpy as np
type(np.nan)
# Out:
# float

# %%
'''
NaN --> Numbers as their values(float)
None --> Non number entries(String, object)
'''
# Out:
# '\nNaN --> Numbers as their values(float)\nNone --> Non number entries(String, object)\n'

# %%
# Retuens Boolean
df.isna()
# Out:
#    username  user_id  sur_name  income
# 0     False    False     False   False
# 1     False    False     False   False
# 2     False    False     False    True
# 3     False    False     False    True
# 4     False    False     False   False
# 5     False    False     False   False
# 6     False    False     False   False

# %%
# Default axis = 0, which means it picks each columns and perform sum
df.isna().sum()
# axis = 0 -> summing operation is performed vertically
# Out:
# username    0
# user_id     0
# sur_name    0
# income      2
# dtype: int64

# %%
# It picks each row and perform sum
df.isna().sum(axis = 1) #It picks each row and perform sum
# axis = 1 -> summing operation is performed horizontally
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# 5    0
# 6    0
# dtype: int64

# %%
# Returns total number of null values
df.isna().sum().sum()
# Out:
# 2

# %% [markdown]
# ## <font color="orange">**10.2) Dealing with missing values**</font>
#
# - Filling null -> imputation
# - Drop null

# %% [markdown]
# ### <font color="morange">**Filling null values -> `data_frame.fillna()`**</font>

# %%
# Filling null values with value 0
df.fillna(0)
# Out:
#   username  user_id sur_name  income
# 0        a        1   Magesh  1000.0
# 1        b        2  Thanesh  2000.0
# 2        a        3   Kamesh     0.0
# 3        d        4      Ram     0.0
# 4        e        5    Shyam  4000.0
# 5        f        6  Vignesh  6000.0
# 6        g        7    Shiva  7000.0

# %%
# Filling nulls with mean values of income:
mean_income = df["income"].mean()

filled_null_df = df.fillna(mean_income)
filled_null_df
# Out:
#   username  user_id sur_name  income
# 0        a        1   Magesh  1000.0
# 1        b        2  Thanesh  2000.0
# 2        a        3   Kamesh  4000.0
# 3        d        4      Ram  4000.0
# 4        e        5    Shyam  4000.0
# 5        f        6  Vignesh  6000.0
# 6        g        7    Shiva  7000.0

# %% [markdown]
# ### <font color="morange">**Dropping null values -> `data_frame.dropna()`**</font>

# %%
# Drops all rows having nulls, default axis = 0
df.dropna() # inplace = True for dropping permanently
# Out:
#   username  user_id sur_name  income
# 0        a        1   Magesh  1000.0
# 1        b        2  Thanesh  2000.0
# 4        e        5    Shyam  4000.0
# 5        f        6  Vignesh  6000.0
# 6        g        7    Shiva  7000.0

# %%
# Drops all cols having nulls
df.dropna(axis = 1) # inplace = True for dropping permanently
# Out:
#   username  user_id sur_name
# 0        a        1   Magesh
# 1        b        2  Thanesh
# 2        a        3   Kamesh
# 3        d        4      Ram
# 4        e        5    Shyam
# 5        f        6  Vignesh
# 6        g        7    Shiva

# %% [markdown]
# # <font color="red">**11) DATA RESTRUCTURING**</font>

# %% [markdown]
# ## <font color="orange">**11.1) Melt (Wide -> Long)**</font>
#
# ![image.png](data:image/png;base64,...)

# %%
# Loading dataset:
import numpy as np
data_drug = pd.read_csv("/content/drive/MyDrive/Dataset for Pandas cheat sheet/Pfizer_1.csv")
data_drug.head(10)
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5  15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6  16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7  16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8  16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9  16-10-2020      docetaxel injection     Pressure     23.0     24.0
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# ...

# %%
# Melt (Wide -> Long):
pd.melt(data_drug, id_vars = ["Date","Drug_Name","Parameter"]).head(10)
# What you are giving in the id_vars will not be changed or pivoted.
# Out:
#          Date                Drug_Name    Parameter variable  value
# 0  15-10-2020  diltiazem hydrochloride  Temperature  1:30:00   23.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure  1:30:00   12.0
# 2  15-10-2020      docetaxel injection  Temperature  1:30:00    NaN
# 3  15-10-2020      docetaxel injection     Pressure  1:30:00    NaN
# 4  15-10-2020   ketamine hydrochloride  Temperature  1:30:00   24.0
# 5  15-10-2020   ketamine hydrochloride     Pressure  1:30:00    8.0
# 6  16-10-2020  diltiazem hydrochloride  Temperature  1:30:00   34.0
# 7  16-10-2020  diltiazem hydrochloride     Pressure  1:30:00   18.0
# 8  16-10-2020      docetaxel injection  Temperature  1:30:00   46.0
# 9  16-10-2020      docetaxel injection     Pressure  1:30:00   23.0

# %%
# Melt (Wide -> Long):
# To change the default variable and value column name:
data_melt = pd.melt(data_drug, id_vars = ["Date","Drug_Name","Parameter"],
                          var_name = "time",
                          value_name = "reading"
                   )
data_melt.head()
# Out:
#          Date                Drug_Name    Parameter     time  reading
# 0  15-10-2020  diltiazem hydrochloride  Temperature  1:30:00     23.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure  1:30:00     12.0
# 2  15-10-2020      docetaxel injection  Temperature  1:30:00      NaN
# 3  15-10-2020      docetaxel injection     Pressure  1:30:00      NaN
# 4  15-10-2020   ketamine hydrochloride  Temperature  1:30:00     24.0

# %% [markdown]
# ## <font color="orange">**11.2) Pivot (Long -> Wide)**</font>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### <font color="morange">**11.2.1) Long -> Wide format 1**</font>

# %%
data_melt.head()
# Out:
#          Date                Drug_Name    Parameter     time  reading
# 0  15-10-2020  diltiazem hydrochloride  Temperature  1:30:00     23.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure  1:30:00     12.0
# 2  15-10-2020      docetaxel injection  Temperature  1:30:00      NaN
# 3  15-10-2020      docetaxel injection     Pressure  1:30:00      NaN
# 4  15-10-2020   ketamine hydrochloride  Temperature  1:30:00     24.0

# %%
# Format 1:
data_melt.pivot(
                 index = ["Date","Drug_Name","Parameter"],
                 columns = "time",
                 values = "reading"
               )
# Out:
# time                                            10:30:00  11:30:00  12:30:00  \
# Date       Drug_Name               Parameter
# 15-10-2020 diltiazem hydrochloride Pressure         18.0      19.0      20.0
#                                    Temperature      20.0      20.0      21.0
#            docetaxel injection     Pressure         26.0      29.0      28.0
#                                    Temperature      23.0      25.0      25.0
#            ketamine hydrochloride  Pressure          9.0       9.0      11.0
#                                    Temperature      22.0      21.0      20.0
# 16-10-2020 diltiazem hydrochloride Pressure         24.0       NaN      27.0
#                                    Temperature      40.0       NaN      42.0
#            docetaxel injection     Pressure         28.0      29.0      30.0
#                                    Temperature      56.0      57.0      58.0
#            ketamine hydrochloride  Pressure         16.0      17.0      18.0
# ...

# %%
data_melt.pivot(
                 index = ["Date","Drug_Name","Parameter"],
                 columns = "time",
                 values = "reading"
               ).reset_index()
# Out:
# time        Date                Drug_Name    Parameter  10:30:00  11:30:00  \
# 0     15-10-2020  diltiazem hydrochloride     Pressure      18.0      19.0
# 1     15-10-2020  diltiazem hydrochloride  Temperature      20.0      20.0
# 2     15-10-2020      docetaxel injection     Pressure      26.0      29.0
# 3     15-10-2020      docetaxel injection  Temperature      23.0      25.0
# 4     15-10-2020   ketamine hydrochloride     Pressure       9.0       9.0
# 5     15-10-2020   ketamine hydrochloride  Temperature      22.0      21.0
# 6     16-10-2020  diltiazem hydrochloride     Pressure      24.0       NaN
# 7     16-10-2020  diltiazem hydrochloride  Temperature      40.0       NaN
# 8     16-10-2020      docetaxel injection     Pressure      28.0      29.0
# 9     16-10-2020      docetaxel injection  Temperature      56.0      57.0
# 10    16-10-2020   ketamine hydrochloride     Pressure      16.0      17.0
# ...

# %% [markdown]
# ### <font color="morange">**11.2.2) Long -> Wide in a good format**</font>

# %%
data_melt.head()
# Out:
#          Date                Drug_Name    Parameter     time  reading
# 0  15-10-2020  diltiazem hydrochloride  Temperature  1:30:00     23.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure  1:30:00     12.0
# 2  15-10-2020      docetaxel injection  Temperature  1:30:00      NaN
# 3  15-10-2020      docetaxel injection     Pressure  1:30:00      NaN
# 4  15-10-2020   ketamine hydrochloride  Temperature  1:30:00     24.0

# %% [markdown]
# Now if you notice,
#
# We are **using 2 rows** to log readings for a single experiment.
#
#
# Can we further restructure our data into dividing the Parameter column into T/P?
#
# A format like:
#
# `Date | time | Drug_Name | Pressure | Temperature`
#
#  would be really suitable

# %%
# Format 2:
data_tidy = data_melt.pivot(
                            index = ["Date","time","Drug_Name"],
                            columns = "Parameter",
                            values = "reading"
                           ).reset_index()
data_tidy.head()
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 23.0
# 2                 22.0
# 3                 20.0
# 4                 25.0

# %%
# Removing the parameter column:
data_tidy.columns
# Out:
# Index(['Date', 'time', 'Drug_Name', 'Pressure', 'Temperature'], dtype='object', name='Parameter')

# %%
data_tidy.columns.name
# Out:
# 'Parameter'

# %%
data_tidy.columns.name = None

# %%
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0

# %% [markdown]
# ## <font color="orange">**11.3) Pivot Table (Long -> Wide, used for Aggregation)**</font>
#
# - Alternate to group by
#
# ![image.png](data:image/png;base64,...)

# %%
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0

# %% [markdown]
# <font color="morange">**Q1) For each drug and on each date, what is the avg temperature?**</font>

# %%
# Apply groupby concept
# For each drug and on each date, what is the avg temperature
data_tidy.groupby(["Drug_Name","Date"])["Temperature"].mean().reset_index().head()
# Out:
#                  Drug_Name        Date  Temperature
# 0  diltiazem hydrochloride  15-10-2020    21.454545
# 1  diltiazem hydrochloride  16-10-2020    37.454545
# 2  diltiazem hydrochloride  17-10-2020    15.636364
# 3      docetaxel injection  15-10-2020    20.750000
# 4      docetaxel injection  16-10-2020    51.454545

# %%
# Apply Pivot table concept
# For each drug and on each date, what is the avg temperature -> Apply Pivot table
pd.pivot_table(data_tidy,
               index = "Drug_Name",
               columns = "Date",
               values = "Temperature",
               aggfunc = np.mean
               )
# Out:
# Date                     15-10-2020  16-10-2020  17-10-2020
# Drug_Name
# diltiazem hydrochloride   21.454545   37.454545   15.636364
# docetaxel injection       20.750000   51.454545   17.500000
# ketamine hydrochloride    23.555556   11.500000   18.500000

# %% [markdown]
# <font color="morange">**Q2) For each drug and on each date, what is the min temperature?**</font>

# %%
# Apply groupby concept
# For each drug and on each date, what is the min temperature
data_tidy.groupby(["Drug_Name","Date"])["Temperature"].min().reset_index().head()
# Out:
#                  Drug_Name        Date  Temperature
# 0  diltiazem hydrochloride  15-10-2020         20.0
# 1  diltiazem hydrochloride  16-10-2020         34.0
# 2  diltiazem hydrochloride  17-10-2020         10.0
# 3      docetaxel injection  15-10-2020         17.0
# 4      docetaxel injection  16-10-2020         46.0

# %%
# Apply Pivot table concept
# For each drug and on each date, what is the min temperature
result = pd.pivot_table(data_tidy,
                        index = "Drug_Name",
                        columns = "Date",
                        values = "Temperature",
                        aggfunc = np.min
                       )
result
# Out:
# Date                     15-10-2020  16-10-2020  17-10-2020
# Drug_Name
# diltiazem hydrochloride        20.0        34.0        10.0
# docetaxel injection            17.0        46.0        12.0
# ketamine hydrochloride         20.0         8.0        13.0

# %% [markdown]
# <font color="morange">**Q3) For each drug and on each date, what is the avg temperature and pressure?**</font>

# %%
# Apply groupby concept
# For each drug and on each date, what is the avg temperature and pressure
data_tidy.groupby(["Drug_Name","Date"])[["Temperature","Pressure"]].aggregate({
                                                                              "Temperature": "mean",
                                                                              "Pressure": "mean"
                                                                              })
# Out:
#                                     Temperature   Pressure
# Drug_Name               Date
# diltiazem hydrochloride 15-10-2020    21.454545  16.000000
#                         16-10-2020    37.454545  22.545455
#                         17-10-2020    15.636364   7.727273
# docetaxel injection     15-10-2020    20.750000  24.875000
#                         16-10-2020    51.454545  27.000000
#                         17-10-2020    17.500000  24.500000
# ketamine hydrochloride  15-10-2020    23.555556   9.333333
#                         16-10-2020    11.500000  14.800000
#                         17-10-2020    18.500000  11.500000

# %%
# Apply Pivot table concept
# For each drug and on each date, what is the avg temperature and pressure
result = pd.pivot_table(data_tidy,
                        index = "Drug_Name",
                        columns = "Date",
                        values = ["Temperature","Pressure"],
                        aggfunc = np.mean
                       )
result
# Out:
#                           Pressure                       Temperature  \
# Date                    15-10-2020 16-10-2020 17-10-2020  15-10-2020
# Drug_Name
# diltiazem hydrochloride  16.000000  22.545455   7.727273   21.454545
# docetaxel injection      24.875000  27.000000  24.500000   20.750000
# ketamine hydrochloride    9.333333  14.800000  11.500000   23.555556
#
#
# Date                    16-10-2020 17-10-2020
# Drug_Name
# diltiazem hydrochloride  37.454545  15.636364
# docetaxel injection      51.454545  17.500000
# ketamine hydrochloride   11.500000  18.500000

# %% [markdown]
# <font color="morange">**Q4) For each drug and on each date, what is the min and max temperature, min and max pressure?**</font>

# %%
# Apply groupby concept
# For each drug and on each date, what is the min and max temperature, min and max pressure
data_tidy.groupby(["Drug_Name","Date"])[["Temperature","Pressure"]].aggregate({
                                                                              "Temperature": ["min", "max"],
                                                                              "Pressure": ["min", "max"]
                                                                              })
# Out:
#                                    Temperature       Pressure
#                                            min   max      min   max
# Drug_Name               Date
# diltiazem hydrochloride 15-10-2020        20.0  23.0     11.0  24.0
#                         16-10-2020        34.0  42.0     18.0  27.0
#                         17-10-2020        10.0  20.0      3.0  14.0
# docetaxel injection     15-10-2020        17.0  25.0     22.0  29.0
#                         16-10-2020        46.0  58.0     23.0  30.0
#                         17-10-2020        12.0  23.0     20.0  29.0
# ketamine hydrochloride  15-10-2020        20.0  27.0      7.0  11.0
#                         16-10-2020         8.0  15.0     12.0  18.0
#                         17-10-2020        13.0  24.0      8.0  15.0

# %%
# Apply Pivot table concept
# For each drug and on each date, what is the min and max temperature, min and max pressure
result = pd.pivot_table(data_tidy,
                        index = "Drug_Name",
                        columns = "Date",
                        values = ["Temperature","Pressure"],
                        aggfunc = ["min", "max"]
                       )
result
# Out:
#                                min                                    \
#                           Pressure                       Temperature
# Date                    15-10-2020 16-10-2020 17-10-2020  15-10-2020
# Drug_Name
# diltiazem hydrochloride       11.0       18.0        3.0        20.0
# docetaxel injection           22.0       23.0       20.0        17.0
# ketamine hydrochloride         7.0       12.0        8.0        20.0
#
#                                                      max             \
#                                                 Pressure
# Date                    16-10-2020 17-10-2020 15-10-2020 16-10-2020
# Drug_Name
# diltiazem hydrochloride       34.0       10.0       24.0       27.0
# docetaxel injection           46.0       12.0       29.0       30.0
# ketamine hydrochloride         8.0       13.0       11.0       18.0
#
#
#                                    Temperature
# Date                    17-10-2020  15-10-2020 16-10-2020 17-10-2020
# ...

# %% [markdown]
# # <font color="red">**12) CUT**</font>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0

# %%
'''
Bins - Continuous data into catogorical groups
'''
# Syntax:
'''
df["new_col"] = pd.cut(df["continuous_col"], bins = bin_values(in the form of list), labels = label_values(in the form of list))
'''
# Out:
# '\ndf["new_col"] = pd.cut(df["continuous_col"], bins = bin_values(in the form of list), labels = label_values(in the form of list))\n'

# %%
# To categorise the temperature column based on bins:
temp_points = [5, 20, 35, 50, 60]
temp_labels =  ["low", "medium", "high", "very_high"]
data_tidy["temp_cat"] = pd.cut(data_tidy["Temperature"] , bins = temp_points , labels = temp_labels)
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature  \
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0
#
#   temp_cat
# 0      low
# 1   medium
# 2   medium
# 3      low
# 4   medium

# %%
# To count the category value accurance
data_tidy["temp_cat"].value_counts()
# Out:
# temp_cat
# low          45
# medium       30
# high         15
# very_high     5
# Name: count, dtype: int64

# %% [markdown]
# # <font color="red">**13) MISC TOPICS**</font>

# %% [markdown]
# ## <font color="orange">**13.1) String function**</font>

# %%
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature  \
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0
#
#   temp_cat
# 0      low
# 1   medium
# 2   medium
# 3      low
# 4   medium

# %%
'''
We can use .str to apply string function to any column
'''
# Syntax:
'''
df["col].str.function()
'''
# Out:
# '\ndf["col].str.function()\n'

# %% [markdown]
# <font color="morange">**Q) Give the rows of the drug_name that contains the word "hydrochloride"**</font>

# %%
data_tidy["Drug_Name"].str.contains("hydrochloride")
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 103    False
# 104     True
# 105     True
# 106    False
# 107     True
# Name: Drug_Name, Length: 108, dtype: bool

# %%
mask = data_tidy["Drug_Name"].str.contains("hydrochloride")
data_tidy.loc[mask].head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature  \
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 5  15-10-2020  11:30:00   ketamine hydrochloride       9.0         21.0
# 6  15-10-2020  12:30:00  diltiazem hydrochloride      20.0         21.0
#
#   temp_cat
# 0      low
# 2   medium
# 3      low
# 5   medium
# 6   medium

# %% [markdown]
# <font color="morange">**Q) Split the date column based on "-"**</font>

# %%
data_tidy["Date"]
# Out:
# 0      15-10-2020
# 1      15-10-2020
# 2      15-10-2020
# 3      15-10-2020
# 4      15-10-2020
#           ...
# 103    17-10-2020
# 104    17-10-2020
# 105    17-10-2020
# 106    17-10-2020
# 107    17-10-2020
# Name: Date, Length: 108, dtype: object

# %%
data_tidy["Date"].str.split('-')
# Out:
# 0      [15, 10, 2020]
# 1      [15, 10, 2020]
# 2      [15, 10, 2020]
# 3      [15, 10, 2020]
# 4      [15, 10, 2020]
#             ...
# 103    [17, 10, 2020]
# 104    [17, 10, 2020]
# 105    [17, 10, 2020]
# 106    [17, 10, 2020]
# 107    [17, 10, 2020]
# Name: Date, Length: 108, dtype: object

# %%
data_tidy["Date"].str.split('-', expand=True).head()
# Out:
#     0   1     2
# 0  15  10  2020
# 1  15  10  2020
# 2  15  10  2020
# 3  15  10  2020
# 4  15  10  2020

# %% [markdown]
# <font color="morange">**Q) Split the Drug_Name column based on " "**</font>

# %%
data_tidy["Drug_Name"].str.split()
# Out:
# 0      [diltiazem, hydrochloride]
# 1          [docetaxel, injection]
# 2       [ketamine, hydrochloride]
# 3      [diltiazem, hydrochloride]
# 4          [docetaxel, injection]
#                   ...
# 103        [docetaxel, injection]
# 104     [ketamine, hydrochloride]
# 105    [diltiazem, hydrochloride]
# 106        [docetaxel, injection]
# 107     [ketamine, hydrochloride]
# Name: Drug_Name, Length: 108, dtype: object

# %%
data_tidy["Drug_Name"].str.split(expand=True)
# Out:
#              0              1
# 0    diltiazem  hydrochloride
# 1    docetaxel      injection
# 2     ketamine  hydrochloride
# 3    diltiazem  hydrochloride
# 4    docetaxel      injection
# ..         ...            ...
# 103  docetaxel      injection
# 104   ketamine  hydrochloride
# 105  diltiazem  hydrochloride
# 106  docetaxel      injection
# 107   ketamine  hydrochloride
#
# [108 rows x 2 columns]

# %% [markdown]
# ## <font color="orange">**13.2) Datetime**</font>

# %%
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature  \
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0
#
#   temp_cat
# 0      low
# 1   medium
# 2   medium
# 3      low
# 4   medium

# %%
data_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         108 non-null    object
#  1   time         108 non-null    object
#  2   Drug_Name    108 non-null    object
#  3   Pressure     95 non-null     float64
#  4   Temperature  95 non-null     float64
#  5   temp_cat     95 non-null     category
# dtypes: category(1), float64(2), object(3)
# memory usage: 4.6+ KB

# %%
'''
Converts to Date time objects
'''
# Syntax:
'''
pd.to_datatime(df["col"])
'''
# Out:
# '\npd.to_datatime(df["col"])\n'

# %%
# Creating a time stamp column by concatinating date and time column
data_tidy["timestamp"] = data_tidy["Date"] + " " + data_tidy["time"]
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature  \
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0
#
#   temp_cat            timestamp
# 0      low  15-10-2020 10:30:00
# 1   medium  15-10-2020 10:30:00
# 2   medium  15-10-2020 10:30:00
# 3      low  15-10-2020 11:30:00
# 4   medium  15-10-2020 11:30:00

# %%
#To convert timestamp col datatype = object to datatype = datetime
data_tidy["timestamp"] = pd.to_datetime(data_tidy["timestamp"])

# %%
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature  \
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0
#
#   temp_cat           timestamp
# 0      low 2020-10-15 10:30:00
# 1   medium 2020-10-15 10:30:00
# 2   medium 2020-10-15 10:30:00
# 3      low 2020-10-15 11:30:00
# 4   medium 2020-10-15 11:30:00

# %%
data_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         108 non-null    object
#  1   time         108 non-null    object
#  2   Drug_Name    108 non-null    object
#  3   Pressure     95 non-null     float64
#  4   Temperature  95 non-null     float64
#  5   temp_cat     95 non-null     category
#  6   timestamp    108 non-null    datetime64[ns]
# dtypes: category(1), datetime64[ns](1), float64(2), object(3)
# memory usage: 5.5+ KB

# %% [markdown]
# <font color="morange">**Q) To extract year, day, month etc**</font>
#
# <font color="morange">**Format-1**</font>

# %%
# To extract the year for the 0th index value
data_tidy["timestamp"][0]
# Out:
# Timestamp('2020-10-15 10:30:00')

# %%
# To extract year, day, month etc
data_tidy["timestamp"][0].year
# Out:
# 2020

# %%
data_tidy["timestamp"][0].day
# Out:
# 15

# %%
data_tidy["timestamp"][0].month
# Out:
# 10

# %%
data_tidy["timestamp"][0].month_name()
# Out:
# 'October'

# %% [markdown]
# <font color="morange">**Format-2**</font>

# %%
# To extract year from the whole column
data_tidy["timestamp"].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 103    2020
# 104    2020
# 105    2020
# 106    2020
# 107    2020
# Name: timestamp, Length: 108, dtype: int32

# %%
# To extract day from the whole column
data_tidy["timestamp"].dt.day
# Out:
# 0      15
# 1      15
# 2      15
# 3      15
# 4      15
#        ..
# 103    17
# 104    17
# 105    17
# 106    17
# 107    17
# Name: timestamp, Length: 108, dtype: int32

# %% [markdown]
# <font color="morange">**Format-3**</font>

# %%
# Formats the select date(0th index) into required format(Here month and year)
data_tidy["timestamp"][0].strftime('%Y')
# Out:
# '2020'

# %%
data_tidy["timestamp"][0].strftime('%m')
# Out:
# '10'

# %%
data_tidy["timestamp"][0].strftime('%d')
# Out:
# '15'

# %%
type(data_tidy["timestamp"][0].strftime('%d'))
# Out:
# str

# %% [markdown]
# # <font color="red">**14) DATA VIZ**</font>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  gender   profit  \
# 0         4762  2009   Dec  Thursday      James Cameron       0  2550.97
# 1         4763  2007   May  Saturday     Gore Verbinski       0   661.00
# 2         4764  2015   Oct    Monday         Sam Mendes       0   635.67
# ...

# %%
data['risky'] = data['risky'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_x           1465 non-null   int64
#  1   budget         1465 non-null   float64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   float64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   director_id    1465 non-null   int64
#  8   year           1465 non-null   int64
#  9   month          1465 non-null   object
#  10  day            1465 non-null   object
#  11  director_name  1465 non-null   object
#  12  gender         1465 non-null   int64
#  13  profit         1465 non-null   float64
#  14  risky          1465 non-null   category
# dtypes: category(1), float64(4), int64(6), object(4)
# memory usage: 161.9+ KB

# %% [markdown]
# ## <font color="orange">**14.1) Basic plt.plot()**</font>

# %% [markdown]
# <font color="morange">**Q) Top 5 active years based on movie count**</font>

# %%
each_year_movie_count = data.groupby('year')['title'].count().reset_index()
each_year_movie_count.head()
# Out:
#    year  title
# 0  1976      3
# 1  1977      6
# 2  1978      5
# 3  1979      4
# 4  1980      8

# %%
each_year_movie_count.sort_values(['title'],ascending=False).head(5)
# Out:
#     year  title
# 30  2006     73
# 29  2005     71
# 26  2002     69
# 35  2011     67
# 32  2008     67

# %%
# Top 5 active years based on movie count
each_year_movie_count.sort_values(['title'],ascending=False).head(5).plot(x='year', y='title', kind='bar')

plt.title("Top 5 active years based on movie count", fontsize=12)
plt.xlabel("Year")
plt.ylabel("Couunt")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## <font color="orange">**14.2) Univariate Data Analysis**</font>

# %% [markdown]
# ### <font color="morange">**14.2.1) Categorical data**</font>

# %% [markdown]
# #### **14.2.1.1) Count and Pie plot**

# %%
plt.figure(figsize=(14,5))

plt.subplot(1,2,1)
sns.countplot(data=data, x='risky', hue='risky')
plt.title("Bar plot", fontsize=12)

plt.subplot(1,2,2)
data['risky'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Pie plot", fontsize=12)

plt.suptitle("Bar and Pie", fontsize=14)
plt.tight_layout()
plt.show()

# %%
labels = data.groupby('month')['month'].count().index
values = data.groupby('month')['month'].count().values

plt.pie(values, labels = labels, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### <font color="morange">**14.2.2) Numerical data**</font>

# %% [markdown]
# #### **14.2.2.1) Histogram**

# %%
sns.histplot(data=data, x='budget')
plt.show()

# %% [markdown]
# ####  **14.2.2.2) KDE Plot**

# %%
sns.kdeplot(data=data, x='popularity')
plt.show()

# %% [markdown]
# ####  **14.2.2.3) Box Plot**

# %%
sns.boxplot(data=data, x='revenue')
plt.show()

# %% [markdown]
# ## <font color="orange">**14.3) Bivariate Data Analysis**</font>

# %% [markdown]
# ### <font color="morange">**14.3.1) Numerical - Numerical**</font>

# %% [markdown]
# #### **14.3.1.1) Line plot**

# %%
plt.figure(figsize=(16,5))
sns.lineplot(data=data, x='year', y='revenue')
plt.title("Revenue of Movies over years")
plt.show()

# %% [markdown]
# #### **14.3.1.2) Scatter plot**

# %%
sns.scatterplot(data=data, x='budget', y='revenue')
plt.show()

# %%
sns.scatterplot(data=data, x='popularity', y='vote_average')
plt.show()

# %% [markdown]
# ### <font color="morange">**14.3.2) Categorical - Categorical**</font>

# %% [markdown]
# #### **14.3.2.1) Dodged barplot**

# %%
sns.countplot(data=data, x='day', hue='risky')
plt.show()

# %% [markdown]
# #### **14.3.2.1) Stacked barplot**

# %%
sns.countplot(data=data, x='day', hue='risky', dodge=False)
plt.show()

# %% [markdown]
# ### <font color="morange">**14.3.3) Categorical - Numerical**</font>

# %% [markdown]
# #### **14.3.3.1) Box plot**

# %%
sns.boxplot(data=data, x='day', y='revenue')
plt.show()

# %% [markdown]
# #### **14.3.3.2) Bar plot**

# %% [markdown]
# **Error bars**
#
# > The "lines" in a Seaborn barplot are error bars representing the uncertainty or variability in the height of the bars. These are typically 95% confidence intervals by default, but can be customized to show standard deviations or turned off entirely.

# %%
sns.barplot(data=data, x='day', y='revenue', hue='day')
plt.show()

# %%
data.groupby('day')['revenue'].describe()
# Out:
#            count        mean         std  min      25%      50%       75%  \
# day
# Friday     654.0   94.578960  129.309247  0.0   9.3550   46.330  132.3300
# Monday      67.0  182.437612  250.159328  0.0  28.9000   97.010  233.2650
# Saturday    47.0  153.031702  273.062449  0.0   6.1800   43.310  161.0700
# Sunday      46.0  102.006522  138.266547  0.0   8.8875   45.275  162.4575
# Thursday   277.0  151.912888  220.532784  0.0  41.9500  101.370  184.3800
# Tuesday     98.0  238.382245  303.255265  0.0  39.5750  142.650  317.7325
# Wednesday  276.0  211.822319  247.166384  0.0  38.4475  123.705  301.3950
#
#                max
# day
# Friday      976.48
# Monday     1118.89
# Saturday   1045.71
# Sunday      709.83
# Thursday   2787.97
# Tuesday    1845.03
# Wednesday  1506.25

# %%
sns.barplot(data=data, x='day', y='revenue', hue='day', ci='sd')
plt.show()

# %%
sns.barplot(data=data, x='day', y='revenue', hue='day', ci=None)
plt.show()

# %% [markdown]
# ## <font color="orange">**14.4) Multivariate Data Analysis**</font>

# %% [markdown]
# ### <font color="morange">**14.4.1) Numerical - Numerical - Categorical**</font>

# %% [markdown]
# #### **14.4.1.1) Scatter plot with colour**

# %%
sns.scatterplot(data=data, x='popularity', y='vote_average', hue='risky')
plt.show()

# %% [markdown]
# ### <font color="morange">**14.4.2) Categorical - Categorical - Numerical**</font>

# %% [markdown]
# #### **14.4.2.1) Doged box plot**

# %%
sns.boxplot(data=data, x='day', y='revenue', hue='risky')
plt.show()

# %% [markdown]
# ### <font color="morange">**14.4.3) Numerical - Numerical - Numerical**</font>

# %% [markdown]
# #### **14.4.3.1) Bubble Chart**

# %%
sns.scatterplot(data=data, x='budget', y='revenue', size='vote_average', sizes=(10,100))
plt.show()

# %% [markdown]
# ## <font color="orange">**14.5) Correlation and Heatmap**</font>

# %%
# Creating numrical dataframe
numerical_data = data.select_dtypes(include='number')

# %%
plt.figure(figsize=(14, 5))
sns.heatmap(numerical_data.corr(), annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# By
#
# SANKARAN MEENAKSHI SUNDARAM
#
# MS in Computer Science: Artificial Intelligence and Machine Learning
#
# Scaler neovarsity, a constituent member college of woolf
